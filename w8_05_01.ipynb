# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime = pd.read_csv("https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/US_Crime_Rates_1960_2014.csv")

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime['Year'] = pd.to_datetime(crime['Year'], format = '%Y')
print(crime['Year'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime.index = crime.Year
crime.head()
# Out:
#                  Year  Population    Total  Violent  Property  Murder  \
# Year
# 1960-01-01 1960-01-01   179323175  3384200   288460   3095700    9110
# 1961-01-01 1961-01-01   182992000  3488000   289390   3198600    8740
# 1962-01-01 1962-01-01   185771000  3752200   301510   3450700    8530
# 1963-01-01 1963-01-01   188483000  4109500   316970   3792500    8640
# 1964-01-01 1964-01-01   191141000  4564600   364220   4200400    9360
#
#             Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# Year
# 1960-01-01          17190   107840              154320    912100
# 1961-01-01          17220   106670              156760    949600
# 1962-01-01          17550   110860              164570    994300
# 1963-01-01          17650   116470              174210   1086400
# 1964-01-01          21420   130390              203050   1213200
#
#             Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01        1855400         328200
# 1961-01-01        1913000         336000
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime = crime.drop('Total',axis = 1)
crime.head()
# Out:
#                  Year  Population  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01 1960-01-01   179323175   288460   3095700    9110          17190
# 1961-01-01 1961-01-01   182992000   289390   3198600    8740          17220
# 1962-01-01 1962-01-01   185771000   301510   3450700    8530          17550
# 1963-01-01 1963-01-01   188483000   316970   3792500    8640          17650
# 1964-01-01 1964-01-01   191141000   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
columns = ['Violent','Property','Murder','Forcible_Rape','Robbery','Aggravated_assault','Burglary','Larceny_Theft','Vehicle_Theft']
b = crime['Year'].dt.year // 10 * 10
a = crime.groupby(b)[columns]
a.sum()
# Out:
#        Violent   Property  Murder  Forcible_Rape  Robbery  Aggravated_assault  \
# Year
# 1960   4134930   45160900  106180         236720  1633510             2158520
# 1970   9607930   91383800  192230         554570  4159020             4702120
# 1980  14074328  117048900  206439         865639  5383109             7619130
# 1990  17527048  119053499  211664         998827  5748930            10568963
# 2000  13968056  100944369  163068         922499  4230366             8652124
# 2010   6072017   44095950   72867         421059  1749809             3764142
#
#       Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960  13321100       26547700        5292100
# 1970  28486000       53157800        9739900
# 1980  33073494       72040253       11935411
# 1990  26750015       77679366       14624418
# 2000  21565176       67970291       11412834
# 2010  10125170       30401698        3569080

# %%
crime.groupby(crime['Year'].dt.year // 10 * 10)['Violent','Property','Murder','Forcible_Rape','Robbery','Aggravated_assault','Burglary','Larceny_Theft','Vehicle_Theft'].sum()
# Out:
# <ipython-input-42-2c2b89ce8312>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   crime.groupby(crime['Year'].dt.year // 10 * 10)['Violent','Property','Murder','Forcible_Rape','Robbery','Aggravated_assault','Burglary','Larceny_Theft','Vehicle_Theft'].sum()
#        Violent   Property  Murder  Forcible_Rape  Robbery  Aggravated_assault  \
# Year
# 1960   4134930   45160900  106180         236720  1633510             2158520
# 1970   9607930   91383800  192230         554570  4159020             4702120
# 1980  14074328  117048900  206439         865639  5383109             7619130
# 1990  17527048  119053499  211664         998827  5748930            10568963
# 2000  13968056  100944369  163068         922499  4230366             8652124
# 2010   6072017   44095950   72867         421059  1749809             3764142
#
#       Burglary  Larceny_Theft  Vehicle_Theft
# Year
# ...

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
index = crime['Murder'].idxmax()
index
# Out:
# Timestamp('1991-01-01 00:00:00')

# %%
print(crime.loc[index])
# Out:
# Year                  1991-01-01 00:00:00
# Population                      252177000
# Violent                           1911770
# Property                         12961100
# Murder                              24700
# Forcible_Rape                      106590
# Robbery                            687730
# Aggravated_assault                1092740
# Burglary                          3157200
# Larceny_Theft                     8142200
# Vehicle_Theft                     1661700
# Name: 1991-01-01 00:00:00, dtype: object
